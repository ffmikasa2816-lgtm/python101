# %% [markdown]
# <a href="https://colab.research.google.com/github/ffmikasa2816-lgtm/python101/blob/main/CAMT_Gifted_week_1%262_Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variable, Input and Output
#
# - **Variables**
#   - **Types and Objects**
#   - **Typecast: `int`, `str`, `float`, and `bool`**
# - **Getting User Input**
# - **Formatting Strings using the placeholders**
# - **Input-Process-Output Pattern**

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#00A0B2">
# Variables</h1>
#
# - When coding, we often want Python to <em style="color:blue">remember</em> some value for later use.
# - We need to pick a name for that value to be remembered and we can use that name to retrieve the value later.
# - We use the term <em style="color:blue">variable</em> to refer to the names we use to refer to this stored data. **You can think of a variable as a name, label or tag.**
# - The assignment operator (`=`) simply creates an association between a name and a value.

# %%
cookie = 30 * 3
print(cookie)
print(type(cookie))
# Out:
# 90
# <class 'int'>

# %%
juice = 60 * 5.0
print(juice)
print(type(juice))
# Out:
# 300.0
# <class 'float'>

# %%
print(cookie + juice)
# Out:
# 390.0

# %%
greeting = 'Hello'
name = 'Joe'
print(greeting + ', ' + name)
# Out:
# Hello, Joe

# %% [markdown]
# ### Variables can be assigned to any type of data.
#
# Although each value has an associated type such as an integer or string, **variable names are untyped** and can be made to refer to any type of data during execution.
#
# ```python
# actor = 'Chris Hemsworth'     # A string, Chris Hemsworth, is assigned to variable "actor"
# inventory = 1000              # An integer, 1000, is assigned to variable "inventory"
# weight = 62.5                 # A floating point number, 62.5, is assigned to variable "weight"
# ```
#
# Variable names can be bound to different values, possibly of varying types, during program execution.
#
# ```python
# x = 37
# x = 'Hello World'
# ```
#
# Python also allows single/multiple assignment to multiple variables at the same time.
#
# ``` python
# # Assigned single value to multiple variables.
# x = y = z = 28             #An integer, 28, is assigned to variable "x", "y", and "z".
# print(x,y,z)
# ```
#
# ``` python
# #Assigned multiple values to multiple variables.
# x, y, z = 28, 1.22,"Hello world"            #An integer, 28, is assigned to variable "x".
#                                             #A floating point, 1.22, is assigned to variable "y".
#                                             #A string, Hello world, is assigned to variable "z".
# print(x,y,z)
# ```

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#B24C00">
# Example1: Assigned single value to multiple variables.</h1>

# %%
x = y = z = 28
print(x,y,z)
# Out:
# 28 28 28

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#B24C00">
# Example2: Assigned multiple values to multiple variables.</h1>

# %%
x, y, z = 28, 1.22,"Hello world"
print(x,y,z)
# Out:
# 28 1.22 Hello world

# %%
x = 37
print(x)
x = 'Hello World'
print(x)
# Out:
# 37
# Hello World

# %%
x, y, z = 28, 1.22,"Hello world"
print(x,':',y,':',z)
# Out:
# 28 : 1.22 : Hello world

# %% [markdown]
# ## Variable name
#
# **The rules for legal Python names:**
# 1. Names must start with a letter (A-Za-z) or _ (underscore).
# 2. Names cannot start with a number.
# 3. Names can contain only letters, digits, and _: A-Z, a-z, 0-9, and _.
# 4. Names cannot contain space or special character ***(except, '_' ,underscores)***.
# 5. Names must not be a Python keyword.
#
# ```python
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
# ```
# 6. variable names are case sensitive e.g.
#
#
#
# ```
# # Case Sensitive Variable Names
# its = 100
# ITs = False
# iTs = 5.782
# itS = "Coding"
#
# ```

# %%
True = 10

# %%
its = 100
ITs = False
iTs = 5.782
itS = "Coding"

print(its, ITs, iTs, itS)
# Out:
# 100 False 5.782 Coding

# %% [markdown]
# **Additional naming considerations:**
# - Names should be lowercase.
# - Underscore should be used to separate words:
#     - `item_price`
#     - `customer_name`
#     - `stock_symbol`
# - Names should be descriptive.
#     - They reduce the need for comments in the code and make it easier to share code or read code written long ago.
#
# | Purpose     |	Good names                      | Bad names         |
# |-------------|---------------------------------|-------------------|
# | radius of a circle |	radius	                | r               	|
# | interest rate      |	interest_rate           | r,rate           	|
# | current time       |	current_time            | t               	|
# | grade point average |	gpa   	                | g               	|
# | temperature        |	temperature	            | t               	|
#
#
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#B24C00">
# Exercise</h1>
#
# 1) Write a program that does the following:
# - Create a new variable `student_name`, and assign it a string value.
# - Print the value of `student_name`.
# - Assign `student_name` a different string value (a different name).
# - Print the value of `student_name`.
# - Assign and print a third value to `student_name`.

# %%
# We can reassign the value to the same variable.
student_name = "Pikul Vejjanugraha"
print(student_name)
student_name = "gifted student"
print(student_name)
# Out:
# Pikul Vejjanugraha
# gifted student

# %% [markdown]
# 2) Write a program that does the following:
# - Create a new variable `x`, and assign it the value `10.5`.
# - Create a new variable `y`, and assign it the value `4`.
# - Sum x and y, and make `x` refer to the resulting value. After this statement has been executed, what are `x` and `y`’s values?

# %%
x=10.5
y=4
x=x+y
print("output is ", x,y)
# Out:
# output is  14.5 4

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#00A0B2">
# Types and Objects</h1>
#
# In assignment, we associate a value with a variable. What exactly is that value?
#
# Every piece of data stored in a program is an object. Each object has an identity, a value, and a type. For example, when you write:
#
# ```python
# x = 37
# ```
# - An integer object is created with the value of `37`.
# - The identity of an object is the actual memory address of the object.
# - The variable `x` contains the memory address of the object to which it refers.
# - The `type` determines both what an object can be and what can be done to it.
#     - For example, in type `int`, the values are `..., -3, -2, -1, 0, 1, 2, 3, ...` and we have seen that these operators can be applied to those values: `+, -, *, /, //, %, **`.

# %% [markdown]
# ### Built-in function `type()`
#
# You can discover the type of an object using the built-in function `type()`.

# %%
print(type(527))
# Out:
# <class 'int'>

# %%
print(type(37.5))
# Out:
# <class 'float'>

# %%
amount = 97.5
print(type(amount))
# Out:
# <class 'float'>

# %%
student_name = 'Joe Smith'
print(type(student_name))
# Out:
# <class 'str'>

# %% [markdown]
# ### Exploring types
# Let's use the built-in function `type()` to explore different data types in Python:

# %%
print(type(3))
# Out:
# <class 'int'>

# %%
print(type(3.7))
# Out:
# <class 'float'>

# %%
print(type('Hello'))
# Out:
# <class 'str'>

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(type({'Sukanya': '02-727-3051', 'Wimon': '02-727-3081'}))
# Out:
# <class 'dict'>

# %% [markdown]
# ### Common built-in data types
#
# The following table shows the basic data types used in Python.
#
# | Category    | Type Name | Description                             |
# |-------------|-----------|-----------------------------------------|
# | Numbers     | int       | A whole number                          |
# | Numbers     | float     | A floating-point number                 |
# | Booleans    | bool      | A True or False value                   |
# | Collections | str       | A sequence of characters                |
# | Collections | list      | An ordered sequence of values           |
# | Collections | tuple     | An unmodified version of lists          |
# | Collections | dict      | An unordered grouping of key-value pairs|
# | Collections | set       | An unordered grouping of values         |
#
#
# - A <em style="color:blue">collection</em> or <em style="color:blue">container</em> is a single objet that contains multiple elements that are associated with the collection object. In fact, a container or collection is an object that contains references to other objects.
# - Type `str`, `list`, and `tuple` are a special kind of collection called a sequence.
# - A <em style="color:blue">sequence</em> is an object that holds multiple items of data, **stored one after the other**.

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#00A0B2">
# Typecast: <code style="color:inherit">str</code>, <code style="color:inherit">int</code>, <code style="color:inherit">float</code>, <code style="color:inherit">bool</code></h1>
#
# What do you think will happen when you try to run the following code?

# %%
total = 20
print(total,'students are signed up for Python class')
# Out:
# 20 students are signed up for Python class

# %% [markdown]
# - This code causes an error because Python only allows combining *like types*:
#     - **string** + **string**
#     - **number** + **number**
#
# You can use the built-in class `str` to solve this problem:

# %%
total = 20
print(str(total) + ' students are signed up for Python class')
# Out:
# 20 students are signed up for Python class

# %% [markdown]
# In this section, you will learn about the typecast: `str`, `int`, `float` and 'bool'.
#
# ### `str()`
# The built-in class `str` that can convert any value to the string and represents it.

# %%
type(str)

# %%
str(777)

# %%
str(47.6)

# %% [markdown]
# ### `int()`
# The built-in class `int` takes any mathematical value and convert it to interger and represents it.
# - It can take a string containing only digits (possibly with a leading minus sign)
#     - An error occurs when the built-in class `int` is called with a string that contains anything other than digits.
# - It can take a `float` value.
#     - The fractional part will be thrown away.

# %%
int('12345')
# Out:
# 12345

# %%
int('-998')
# Out:
# -998

# %%
int(-99.9)
# Out:
# -99

# %%
int(-99.9)
# Out:
# -99

# %%
int('Hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_501/875039421.py in <cell line: 0>()
# ----> 1 int('Hello')
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# ### `float()`
# The built-in class `float` takes any mathematical value and convert it to `floating` number and represents it.
# - It can take a string containing only digits and zero or one decimal points (possibly with a leading minus sign).
# - It can take an `int` value.

# %%
float('-43.2')
# Out:
# -43.2

# %%
float('432')
# Out:
# 432.0

# %%
float(4)
# Out:
# 4.0

# %%
float('-9.9.9')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_501/2239543496.py in <cell line: 0>()
# ----> 1 float('-9.9.9')
#
# ValueError: could not convert string to float: '-9.9.9'

# %% [markdown]
# ### `bool()`
# The built-in class `bool` takes a speific patterns and convert it to `boolean` value using following equation:
#
#
# $$\text{bool}(x) = \begin{cases}
#     \text{False} & \text{if } x = 0 \text{ or } x = "" \\
#     \text{True} & \text{otherwise}
# \end{cases}$$

# %%
bool(0)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool("0")
# Out:
# True

# %%
bool('Hello world')
# Out:
# True

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#B24C00">
# Exercise</h1>
#
# 1) Write a program that adds the following three numbers as integers and prints the result.

# %%
str_num_1 = '112' #str --> int
str_num_2 = '864' #str --> int
int_num_3 = 10    #int

# int + int + int

a=int(str_num_1)
b=int(str_num_2)
print(a+b+int_num_3)
# your code

# %% [markdown]
# 2) Write a program that does the folowing:
# - Assign `str_integer` variable a string containing characters of an integer.
# - Assign `int_number` variable an integer value.
# - Add the 2 numbers as integers and assign it to `number_total` variable.
# - Print the sum (`number_total`).

# %%
# your code
str_integer='555' # เอาตัวเลข ใส่ไปใน string
int_number=5      # int จะไม่มีจุดทศนิยม

# add = int + int
# add = int(string) + int


number_total=int(str_integer)+int_number
print(number_total)
# Out:
# 560

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#00A0B2">
# Getting User Input</h1>
#
# ### Built-in function `input()`
# - The built-in function `input()` prompts the user to supply data and returns that data as a string.

# %%
num = input('Enter a your favorite number : ')
print(num)
# Out:
# Enter a your favorite number :  30
#  30

# %%
student_name = input('Enter the student name: ')
print('Hi ' + 'student_name')

#     string + string
# Out:
# Enter the student name: may
# Hi student_name

# %% [markdown]
# ### Note on `input()`
#
# The `input()` function returns a string regardless of what you enter.
# - If a string is entered, the `input()` function returns a string
# - if a number is entered, the `input()` function returns a string

# %%
age = input('How old are you? ')
print('Your are ' + age + ' years old.')
print(type(age))
# Out:
# How old are you? ten
# Your are ten years old.
# <class 'str'>

# %% [markdown]
# When performing a math operation on an input value, you might not get the answer you expected.

# %%
age = input('How old are you? ')
print(type(age))  # str --> int
age_in_decade = int(age) + 10
print('Next year student will be ' , age_in_decade)
# Out:
# How old are you? 10
# <class 'str'>
# Next year student will be  20

# %% [markdown]
# How would you fix the error?

# %%
# your code

# %% [markdown]
# As you saw earlier, the `print()` function  can take a comma-separated list of values of any type; so, we can rewrite the above code using this feature:

# %%
# your code

# %% [markdown]
# We can use `input()` and `int()` together in the same line of code:

# %%
age = int(input('How old are you? ')) #กำหนด input ไปเลยว่าเป็น Int ตั้งแต่แรก
age_in_decade = age + 10
print('Next year student will be', age_in_decade)
# Out:
# How old are you? 10
# Next year student will be 20

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#00A0B2">
# Formatting Strings using the placeholders</h1>
#
# - When creating strings to present as messages to the user of a program, you will want to format them in such a way that they are clear and easy to understand.
# - While it is possible to format strings using concatenation (`+`) or text repeatation (`*`), this can quickly become tedious.
# - Fortunately, Python provides a way to set up the format of string called as **" the Placeholder "**
# - Placeholder is a special symbol or **construct** within a string **that marks a position where a value from the output will be inserted later**. Think of it like a blank space in a form that you fill in with specific information.
#
# Python offers several ways to use placeholders for string formatting. Let's explore the most common methods:
#
# ## `%`-formatting (Old-style)
#
# This is the oldest method, similar to how string formatting is done in C. You use special characters (placeholders) following with a string formatting operator (`%`) to indicate where values should be inserted.
#
# **Placeholders:**
#  - `%s`: String
#  - `%d`: Integer
#  - `%f`: Floating-point number (can control up to 6 digit of the floating point)
#
# To use a placeholder, we put the **Placeholders** inside a fixed string
# to hold places for variables.
#
# After the string, insert the string formatting operator (`%`) (not a comma) following with a variable or a list of variables.
#
# **Note that**: The number of placeholders must match with the number of variables.
#
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#B24C00">
# Example</h1>

# %%
name = "Alice"
print("My name is %s" % (name))  # Output: My name is Alice.
# Out:
# My name is Alice

# %%
name = "Alice" #str
age = 30       #int
print("My name is %s and I am %d years old." % (name, age))  # Output: My name is Alice and I am 30 years old.
# Out:
# My name is Alice and I am 30 years old.

# %%
x = 16; y = 26.42; z = 7.569091
print("x = %d, y = %.2f, z = %.2f" %(x,y,z))
# Out:
# x = 16, y = 26.42, z = 7.57

# %%
# What happens if the number of variables does not match the number of placeholders?
x = 16; y = 26.42; z = 7.569091
print("x = %d, y = %.0f, z = %.4f" %(x,y,z))
print(type(y))
# Out:
# x = 16, y = 26, z = 7.5691
# <class 'float'>

# %% [markdown]
#  ## `f-strings` format (Modern-style)
#
#  f-strings offer the most concise and readable way to format strings. You prefix the string with `f` and embed expressions directly inside curly braces `{}`.
#
#  **Placeholders**: Expressions within curly braces `{}`.
#
#  <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#B24C00">
# Example</h1>

# %%
name = 'john'
print(f'My name is {name}.') # Output: My name is John.
# Out:
# My name is john.

# %% [markdown]
# Python will look in the placeholder and evaluate the code there. Note that the placeholder can contain function calls, method calls, or any other arbitrary code:

# %%
age = int(input('How old are you? '))
print(type(age))
print(f'Next ten year, you will be {age + 10} year old')
# Out:
# How old are you? 10
# <class 'int'>
# Next ten year, you will be 20 year old

# %%
number = 25
print(f'Square root of {number} is {number**.5}')
# Out:
# Square root of 25 is 5.0

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#B24C00">
# Exercise</h1>
#
# 1) Write a program that asks the user to enter the name of a city and prints `"The city name is "` followed by the user input.

# %%
# your code
city = (input('เมืองนี้ชื่ออะไร? '))
print(f"This city name is {city}")
# Out:
# เมืองนี้ชื่ออะไร? cnx
# This city name is cnx

# %% [markdown]
# 2) Write a program that asks the user to enter two integer numbers, performs addition, and prints the two numbers followed by the result.
#
# &nbsp; &nbsp; *Output Example:*
#
# &nbsp; &nbsp; `9 + 13 = 22`

# %%
# your code
x_str, y_str,z_str = input('input 3 numbers separated by a comma: ').split(',')
x = int(x_str)
y = int(y_str)
z = int(z_str)
total = x + y + z
print(f'{x} + {y} + {z} = {total}')

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#00A0B2">
# Input-Process-Output Pattern</h1>
#
# Input-Process-Output (IPO) pattern is one of basic program structures. It
# starts from accepting a number of inputs from a user. Then, it performs a
# number of operations to generate an output. Finally, the output is displayed to
# the user.
#
# ![Input-Process-Output Pattern.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# <h1 style="font-size:1.5em; font-family: verdana, Geneva, sans-serif; color:#B24C00">
# Example</h1>
#
# 1) Write a program that accepts the width (*`w`* ) and the height (*`h`*) of a rectangle. Then, calculate and displays the area (*`a`*) of the rectangle from the formula below.
#
# $$a = w \times h$$

# %%
# INPUT
width = input("Enter the width: ")
height = input("Enter the height: ")
# PROCESS
width = float(width)
height = float(height)
area = width*height
# OUTPUT
print(f"The area of the rectangle = {area}")

# %% [markdown]
# 2) Write a program that accepts a temperature in kelvin (*`k`*) from a user. The program then converts the temperature to degree celsius and displays the result with 2 digits after the decimal point.
#
# $$c = k - 273.15$$

# %%
# INPUT
kelvin = input("Input the temperature in kelvin: ")
# PROCESS

celsius= float(kelvin)-273.15


# OUTPUT
print(f"Temperature in degree celsius: {celsius}")

# %% [markdown]
# 3) Write a program that accepts a temperature in degree celsius (*`c`*). It then converts the temperature to degree fahrenheit (*`f`*) and displays the result with 2 digits after the decimal point.
#
# $$f = \frac{9c}{5} + 32$$

# %%
# INPUT
celsius = input("Input the temperature in degree celsius: ")
# PROCESS

fahrenheit = (9*float(celsius)/5)+32

# OUTPUT
print(f"Temperature in degree fahrenhit: {fahrenheit:.2f}")

# %% [markdown]
# 4) The **stone, pound,** and **ounce** are English units of mass, where
# - 1 stone is equal to 14 pounds
# - 1 pound is equal to 16 ounces.
# - 1 kilogram is equal to 2.2 pounds.
#
# Write a program that accepts a mass in **stones, pounds, and ounces** from a user. It then calculates and displays the equivalent mass in **kilograms**.

# %%
# INPUT
stone,pound,ounce = input("Input a mass in stones, pounds, ounces:").split()
# PROCESS

kilograms= ((float(stone)*14)+float(pound)+(flote(ounce)/16))/2.2





#OUTPUT
print(f"The equivalent mass in kg = {kilograms:.2f}")

# %%
age = input('How old are you? ')  #output as str
print(type(age))
age_in_decade = int(age) + 10
print('Next year student will be ' + str(age_in_decade))
